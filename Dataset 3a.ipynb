# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re

# %%
def scrape_page(page_url):
    answer = requests.get(page_url)
    content = answer.content
    soup = BeautifulSoup(content, features = 'html.parser')

    return soup

# %%
def extract_listing(page_url):
    page_soup = scrape_page(page_url)
    listings = page_soup.findAll("div", {'class': 'c1l1h97y dir dir-ltr'})
    return listings

# %%
links = ['https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
'https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=844c44da-c517-42db-9331-e2459dfb5a5c&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D',
'https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=844c44da-c517-42db-9331-e2459dfb5a5c&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjozNiwidmVyc2lvbiI6MX0%3D',
'https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=844c44da-c517-42db-9331-e2459dfb5a5c&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo1NCwidmVyc2lvbiI6MX0%3D',
'https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=844c44da-c517-42db-9331-e2459dfb5a5c&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo3MiwidmVyc2lvbiI6MX0%3D',
'https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=844c44da-c517-42db-9331-e2459dfb5a5c&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo5MCwidmVyc2lvbiI6MX0%3D',
'https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes
tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=844c44da-c517-42db-9331-e2459dfb5a5c&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMTYsInZlcnNpb24iOjF9',
'https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=844c44da-c517-42db-9331-e2459dfb5a5c&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMzQsInZlcnNpb24iOjF9',
'https://www.airbnb.com/s/Utah--United-States/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&query=Utah%2C%20United%20States&place_id=ChIJzfkTj8drTIcRP0bXbKVK370&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=844c44da-c517-42db-9331-e2459dfb5a5c&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNTIsInZlcnNpb24iOjF9']

# %%
listings = {'title':[], 'name':[], 'price':[], 'price_unit':[], 'beds':[], 'rating':[], 'superhost': [], 'photos': []}

# %%
for url in links:
    props = extract_listing(url)
    answer = requests.get(url)
    content = answer.content
    soup = BeautifulSoup(content, features = 'html.parser')
    soup.find_all('div', {'class': '_j4dv73'})
    for p in range(len(props)):
        r = requests.get(url)
        if r.ok:
            bs = BeautifulSoup(r.text)
            listings['title'].append(props[p].find('div', {'class': 't1jojoys dir dir-ltr'}))                                  
            listings['name'].append(props[p].find('span', {'class': 't6mzqp7 dir dir-ltr'}))
            listings['price'].append(props[p].find('span', {'class': '_tyxjp1'}))
            listings['price_unit'].append(props[p].find('span', {'class': '_r1nvod'}))
            listings['beds'].append(props[p].find('span', {'class': 'dir dir-ltr'}))
            listings['rating'].append(props[p].find('span', {'class': 'r1dxllyb dir dir-ltr'}))
            listings['superhost'].append(props[p].find('div', {'class': 't1mwk1n0 dir dir-ltr'}))
            listings['photos'].append(f"{props[p].find('div', {'class': '_r752or'})}")

# %%
listings.pop('photos', None)
listings.pop('price_unit', None)

# %%
airbnb = pd.DataFrame(listings)
len(airbnb)
# Out:
# 271

# %%
airbnb = airbnb.replace('None', np.nan)
airbnb = airbnb.dropna(subset = ['price'])
airbnb = airbnb.reset_index(drop = True)

# %%
for i in range(len(airbnb['title'])):
    airbnb['title'][i] = airbnb['title'][i].get_text().strip()
    airbnb['name'][i] = airbnb['name'][i].get_text().strip()
    #airbnb['price'][i] = airbnb['price'][i].get_text().strip()
    airbnb['beds'][i] = airbnb['beds'][i].get_text().strip()
    #airbnb['rating'][i] = airbnb['rating'][i].get_text().strip()

# %%
airbnb['location'] = airbnb['title']

for i in range(len(airbnb['location'])):
    airbnb['location'][i] = airbnb['location'][i].split(' in ')[1]

# %%
airbnb['reviews'] = airbnb['rating']

for i in range(len(airbnb['reviews'])):
    if airbnb['rating'][i] == None:
        airbnb['rating'][i] = np.NaN
    else:
        airbnb['rating'][i] = airbnb['rating'][i].get_text().strip()
        
        if '(' in airbnb['rating'][i]:
            airbnb['reviews'][i] = int(airbnb['rating'][i].split('(')[1][:-1])
        else:
            airbnb['reviews'][i] = np.NaN
        airbnb['rating'][i] = airbnb['rating'][i].split(' (')[0]
        if 'New' in airbnb['rating'][i]:
            airbnb['rating'][i] = np.NaN
        airbnb['rating'][i] = float(airbnb['rating'][i])

# %%
airbnb
# Out:
#                                title  \
# 0                 Treehouse in Nephi
# 1                 Treehouse in Nephi
# 2            Cabin in Fountain Green
# 3    Place to stay in Fountain Green
# 4                   Cabin in Wanship
# ..                               ...
# 206         Guest suite in Bluffdale
# 207               Farm stay in Manti
# 208                Cottage in Vernal
# 209        Private room in Escalante
# 210            Private room in Provo
#
#                                                   name         price  \
# 0                         Fantasy Treehouse and Resort  [$190,  ,  ]
# 1                         Fantasy Treehouse and Resort  [$190,  ,  ]
# 2    Cozy Private Mountain Cabin on 1,000 acre prop...  [$141,  ,  ]
# 3    Luxury Glamping Teepee w/King Bed on private Mtn!  [$122,  ,  ]
# 4       Cozy Cabin with Hot Tub minutes from Park City  [$186,  ,  ]
# ..                                                 ...           ...
# ...

# %%
for i in range(len(airbnb['price'])):
    if airbnb['price'][i] == None:
        airbnb['price'][i] = np.NaN
    else:
        airbnb['price'][i] = airbnb['price'][i].get_text().strip()
        airbnb['price'][i] = int(airbnb['price'][i].replace(',', '')[1:])

# %%
for i in range(len(airbnb['superhost'])):
    if airbnb['superhost'][i] == None:
        airbnb['superhost'][i] = 0
    else:
        airbnb['superhost'][i] = 1

# %%
for i in range(len(airbnb['beds'])):
    airbnb['beds'][i] = int(airbnb['beds'][i][0])

# %%
airbnb['len_name'] = airbnb['name']

for i in range(len(airbnb['len_name'])):
    airbnb['len_name'][i] = len(airbnb['name'][i])

# %%
#airbnb = airbnb.drop_duplicates()

# %%
airbnb.reset_index(drop = True)
# Out:
#                                title  \
# 0                 Treehouse in Nephi
# 1                 Treehouse in Nephi
# 2            Cabin in Fountain Green
# 3    Place to stay in Fountain Green
# 4                   Cabin in Wanship
# ..                               ...
# 206         Guest suite in Bluffdale
# 207               Farm stay in Manti
# 208                Cottage in Vernal
# 209        Private room in Escalante
# 210            Private room in Provo
#
#                                                   name price beds rating  \
# 0                         Fantasy Treehouse and Resort   190    3   4.91
# 1                         Fantasy Treehouse and Resort   190    3   4.91
# 2    Cozy Private Mountain Cabin on 1,000 acre prop...   141    4   4.96
# 3    Luxury Glamping Teepee w/King Bed on private Mtn!   122    2   4.98
# 4       Cozy Cabin with Hot Tub minutes from Park City   186    2   4.96
# ...

# %%
airbnb
# Out:
#                                title  \
# 0                 Treehouse in Nephi
# 1                 Treehouse in Nephi
# 2            Cabin in Fountain Green
# 3    Place to stay in Fountain Green
# 4                   Cabin in Wanship
# ..                               ...
# 206         Guest suite in Bluffdale
# 207               Farm stay in Manti
# 208                Cottage in Vernal
# 209        Private room in Escalante
# 210            Private room in Provo
#
#                                                   name price beds rating  \
# 0                         Fantasy Treehouse and Resort   190    3   4.91
# 1                         Fantasy Treehouse and Resort   190    3   4.91
# 2    Cozy Private Mountain Cabin on 1,000 acre prop...   141    4   4.96
# 3    Luxury Glamping Teepee w/King Bed on private Mtn!   122    2   4.98
# 4       Cozy Cabin with Hot Tub minutes from Park City   186    2   4.96
# ...

# %%
airbnb.to_csv('airbnb.csv')
